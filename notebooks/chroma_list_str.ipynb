# %%
import sys
import os
# setting path
# Aggiungi la cartella PARENT della cartella Parla_con_PG_TM
project_root = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
PERSIST_DIR = project_root + "\Parla_con_PG_TM\chroma_db"

# %%
from chromadb import PersistentClient

# Percorso dove hai salvato il database
client = PersistentClient(path=PERSIST_DIR)

# Nome della collection (es. "my_collection")
collection = client.get_collection("ardania_lore")

# Recupera tutti i documenti
results = collection.get()

# Estrai solo i testi
documents = results["documents"]

print(f"Trovati {len(documents)} documenti.")
print(documents[:3])  # Anteprima
# Out:
# Trovati 12638 documenti.
# ...
