# %%
from llama_parse import LlamaParse
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
parser = LlamaParse(
    api_key=os.getenv("LLAMAPARSE_API_KEY"),
    result_type="json",
    verbose=True,
)

# %%
documents = parser.get_json_result("docs/ardania.pdf")
# Out:
# Started parsing the file under job_id a2794289-c017-4ea0-9bfb-610797cb8e4d

# %%
import json
documents[0]["pages"][0].keys()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import json
# ----> 2 documents[0]["pages"][0].keys()
#
# NameError: name 'documents' is not defined
